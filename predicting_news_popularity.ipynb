# %%
# inline plotting instead of popping out
# %matplotlib inline

import os, itertools, csv, timeit, json, re
from datetime import datetime
from IPython.display import Image
from IPython.display import display
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

# nltk
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
# sklearn
from sklearn.model_selection import train_test_split, KFold, GridSearchCV, cross_val_score

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, HashingVectorizer
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA, TruncatedSVD

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB, ComplementNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, VotingClassifier

from sklearn.metrics import accuracy_score, mean_squared_error, roc_curve, auc, roc_auc_score

# %%
from tqdm import tqdm

tqdm.pandas()

# %%
dirname = './data'
f_train = 'preprocessed_train_2.csv'
f_test = 'preprocessed_test_2.csv'
f_sub = 'sample_submission.csv'
p_train = os.path.join(dirname, f_train)
p_test = os.path.join(dirname, f_test)
p_sub = os.path.join(dirname, f_sub)

# %%
df_train = pd.read_csv(p_train)
df_train.rename(
    columns={'Id': 'id', 'Popularity': 'pop', 'Page content': 'content', 'author scalar': 'author_scalar'}, 
    inplace=True
)
pop_group = df_train.groupby(['pop'])
if 'Unnamed: 0' in df_train.columns:
    df_train.drop(['Unnamed: 0'], axis=1, inplace=True)
df_train.head()
# Out:
#    id  pop                                            content  \
# 0   0   -1  <html><head><div class="article-info"> <span c...
# 1   1    1  <html><head><div class="article-info"><span cl...
# 2   2    1  <html><head><div class="article-info"><span cl...
# 3   3   -1  <html><head><div class="article-info"><span cl...
# 4   4   -1  <html><head><div class="article-info"><span cl...
#
#                                              article  \
# 0  There may be killer asteroids headed for Earth...
# 1  Google took a stand of sorts against patent-la...
# 2  You've spend countless hours training to be an...
# 3   Tired of the same old sports fails and news f...
# 4  At 6-foot-5 and 298 pounds, All-Pro NFL star J...
#
#                                                title  \
# 0  NASA's Grand Challenge: Stop Asteroids From De...
# 1  Google's New Open Source Patent Pledge: We Won...
# 2  Ballin': 2014 NFL Draft Picks Get to Choose Th...
# 3        Cameraperson Fails Deliver Slapstick Laughs
# 4  NFL Star Helps Young Fan Prove Friendship With...
#
#                                               topics   data_channel  see_also  \
# 0  ['Asteroid', 'Asteroids', 'challenge', 'Earth'...          world         1
# 1  ['Apps and Software', 'Google', 'open source',...           tech         1
# 2  ['Entertainment', 'NFL', 'NFL Draft', 'Sports'...  entertainment         1
# 3       ['Sports', 'Video', 'Videos', 'Watercooler']    watercooler         1
# 4  ['Entertainment', 'instagram', 'instagram vide...  entertainment         1
#
#    p_year  p_month  ...  title_pos_tag_7  title_pos_tag_8  title_pos_tag_9  \
# 0  2013.0      6.0  ...               IN              VBG               NN
# 1  2013.0      3.0  ...               NN              PRP               MD
# 2  2014.0      5.0  ...               TO               VB             PRP$
# 3  2013.0     10.0  ...             NONE             NONE             NONE
# 4  2014.0      4.0  ...               NN               IN               JJ
#
#    title_pos_tag_10  title_pos_tag_11 title_pos_tag_12  title_pos_tag_13  \
# 0              NONE              NONE             NONE              NONE
# 1                RB                VB               IN               VBN
# 2                JJ                NN               NN              NONE
# 3              NONE              NONE             NONE              NONE
# 4                NN              NONE             NONE              NONE
#
#    title_pos_tag_14  title_pos_tag_15 num_topics
# 0              NONE              NONE         73
# 1                RB              NONE        122
# 2              NONE              NONE         61
# 3              NONE              NONE         44
# 4              NONE              NONE         66
#
# [5 rows x 37 columns]

# %%
df_test = pd.read_csv(p_test)
df_test.rename(
    columns={'Id': 'id', 'Page content': 'content'}, 
    inplace=True
)
if 'Unnamed: 0' in df_test.columns:
    df_test.drop(['Unnamed: 0'], axis=1, inplace=True)
df_test.head()
# Out:
#       id                                            content  \
# 0  27643  <html><head><div class="article-info"><span cl...
# 1  27644  <html><head><div class="article-info"><span cl...
# 2  27645  <html><head><div class="article-info"><span cl...
# 3  27646  <html><head><div class="article-info"><span cl...
# 4  27647  <html><head><div class="article-info"><span cl...
#
#                                              article  \
# 0   Note to humanity: One Direction fandom ain't ...
# 1  Shortly after announcing a hardware upgrade fo...
# 2  Well, that was quick. Just hours after going o...
# 3   Between Two Ferns: Oscar Buzz Edition Part 1 ...
# 4   Ever since The Hurt Locker it seems like we h...
#
#                                                title  \
# 0  Soccer Star Gets Twitter Death Threats After T...
# 1               Google Glass Gets an Accessory Store
# 2     OUYA Gaming Console Already Sold Out on Amazon
# 3           'Between Two Ferns' Mocks Oscar Nominees
# 4  'American Sniper' Trailer: Looks Like Eastwood...
#
#                                               topics   data_channel  see_also  \
# 0  ['Entertainment', 'Music', 'One Direction', 's...  entertainment         1
# 1  ['Gadgets', 'glass', 'Google', 'Google Glass',...           tech         1
# 2  ['amazon', 'amazon kindle', 'Business', 'Gaming']       business         1
# 3  ['Between Two Ferns', 'Movies', 'The Oscars', ...           film         1
# 4  ['American Sniper', 'Awards', 'Bradley Cooper'...  entertainment         1
#
#    p_year  p_month  p_day  ...  title_pos_tag_7  title_pos_tag_8  \
# 0  2013.0      9.0    9.0  ...               IN              VBG
# 1  2013.0     10.0   31.0  ...             NONE             NONE
# 2  2013.0      6.0   25.0  ...               IN               NN
# 3  2013.0      2.0   13.0  ...              NNS             NONE
# 4  2014.0     10.0    3.0  ...               NN               MD
#
#    title_pos_tag_9  title_pos_tag_10 title_pos_tag_11  title_pos_tag_12  \
# 0               CD                NN               NN              NONE
# 1             NONE              NONE             NONE              NONE
# 2             NONE              NONE             NONE              NONE
# 3             NONE              NONE             NONE              NONE
# 4               VB                RB               IN                DT
#
#    title_pos_tag_13  title_pos_tag_14 title_pos_tag_15  num_topics
# 0              NONE              NONE             NONE          63
# 1              NONE              NONE             NONE          70
# 2              NONE              NONE             NONE          49
# 3              NONE              NONE             NONE          94
# 4                NN              NONE             NONE         104
#
# [5 rows x 36 columns]

# %%
df_test.fillna(0, inplace=True)

# %%
def clean_text(text_to_clean, no_punc=True):
    res = text_to_clean.lower()
    res = re.sub(r"i'm", "i am", res)
    res = re.sub(r"he's", "he is", res)
    res = re.sub(r"she's", "she is", res)
    res = re.sub(r"it's", "it is", res)
    res = re.sub(r"that's", "that is", res)
    res = re.sub(r"what's", "what is", res)
    res = re.sub(r"where's", "where is", res)
    res = re.sub(r"how's", "how is", res)
#     res = re.sub(r"\'s", " is", res)
    res = re.sub(r"\'ll", " will", res)
    res = re.sub(r"\'ve", " have", res)
    res = re.sub(r"\'re", " are", res)
    res = re.sub(r"\'d", " would", res)
    res = re.sub(r"\'re", " are", res)
    res = re.sub(r"won't", "will not", res)
    res = re.sub(r"can't", "cannot", res)
    res = re.sub(r"n't", " not", res)
    res = re.sub(r"n'", "ng", res)
    res = re.sub(r"'bout", "about", res)
    res = re.sub(r"'til", "until", res)
    
    if no_punc:
        res = re.sub(r"[-()\"#/@;:<>{}`+=~|.!?,]", "", res)
    return res

# %%
stop_words = stopwords.words('english')

def preprocessor(text):
    porter = PorterStemmer()
    res = clean_text(text)
    
    tokens = [porter.stem(w) for w in re.split('\s+', res.strip()) \
        if w not in stop_words and re.match('[a-zA-Z]+', w)]
    
    return ' '.join(tokens)

# %% [markdown]
# ## Sample popular & unpopular news

# %%
for c in pop_group.get_group(1).sample(n=5, random_state=1)['content']:
    print(c)
    print('\n\n\n')
# Out:
# <html><head><div class="article-info"><span class="byline "><a href="/author/laura-vitto/"><img alt="2016%2f09%2f21%2f3f%2flauravittoheadshotslowres1.b1191" class="author_image" src="http://i.amz.mshcdn.com/OAcgWfEl5UfjasprN9z1m4SEIXo=/90x90/2016%2F09%2F21%2F3f%2FLauraVittoheadshotslowres1.b1191.jpg"/></a><span class="author_name">By <a href="/author/laura-vitto/">Laura Vitto</a></span><time datetime="Tue, 28 Jan 2014 20:15:47 +0000">2014-01-28 20:15:47 UTC</time></span></div></head><body><h1 class="title">Vin Diesel's 7-Minute Dance Video Is His Greatest Work Yet</h1><figure class="article-image"></figure><article data-channel="entertainment"><section class="article-content"> <p>Vin Diesel is an actor, producer and, apparently, a huge Beyoncé fan.</p> <p>The <em>Fast and the Furious</em> star took to his <a href="http://mashable.com/category/facebook/" target="_blank">Facebook</a> page on Tuesday to share his latest (and possibly greatest) piece of work. The self-recorded clip shows the muscle-bound star showing off his best moves to Katy Perry's "Dark Horse" and Beyoncé's "Drunk in Love".</p> <div class="see-also"><p>See also: <a href="http://mashable.com/2014/01/23/beyonce-parody-morning-face/">Beyoncé Parody Shows Just How Flawless You Look in the Morning</a></p></div> <div id="fb-root"></div> <div class="fb-post" data-href="https://www.facebook.com/photo.php?v=10152278510183313" data-width="466"><div class="fb-xfbml-parse-ignore"><p><a href="https://www.facebook.com/photo.php?v=10152278510183313" target="_blank">Post</a> by <a href="https://www.facebook.com/VinDiesel" target="_blank">Vin Diesel</a>.</p></div></div> <p>Diesel's 63 million Facebook followers are loving the clip, which has amassed nearly 54,000 comments and 500,000 likes in the seven hours since its posting. Others took to Twitter to share their comments.</p> <blockquote class="twitter-tweet" lang="en"> <p>Still laughing about how Vin Diesel pantomimed riding a SURFBORDT.</p> <p>— pam.mie.pie (@ohnopdidnt) <a href="https://twitter.com/ohnopdidnt/statuses/428238259747950592" target="_blank">January 28, 2014</a></p> </blockquote> <blockquote class="twitter-tweet" lang="en"> <p>the most disturbing thing about vin diesel's video is the fact that it's obvious he's holding back.</p> <p>— C.R. (@ChristinaRpr) <a href="https://twitter.com/ChristinaRpr/statuses/428237792921931776" target="_blank">January 
/"><em>Orange Is The New Black</em></a> and <a href="http://mashable.com/category/house-of-cards/"><em>House of Cards</em></a>, or do you crave the suspense that comes from waiting a week for each new episode of such dramas as AMC's <em>Breaking Bad</em> and <em>The Walking Dead</em>?</p> <div class="see-also"><p>See also: <a href="http://mashable.com/2013/12/03/dead-actors-on-screen/">10 Actors Who Appeared on Screen After Their Deaths</a></p></div> <p>Regardless of your criteria, we're curious to hear what kept you glued to the screen in 2013. </p> <p>We rounded up 35 of the year's most widely-watched and critically-acclaimed shows in the poll, below. Vote for your favorite to help us determine the best show of 2013, and tell us why in the comments. You can vote for up to five shows, but if you don't see your choice feel free to add your vote in the comments. The polls will remain open all week, and we'll reveal the results Dec. 17.</p> <script charset="utf-8" src="http://static.polldaddy.com/p/7634411.js" type="text/javascript"></script><p></p> <noscript><a href="http://polldaddy.com/poll/7634411/" target="_blank">What Is Your TV Show of 2013?</a></noscript> <p><strong><div class="bonus-content">BONUS: <a href="http://mashable.com/2013/12/05/tv-characters-okcupid/">If TV Characters Had OKCupid Profiles</a> </div></strong> </p> <section class="gallery" data-display-mode="gallery" data-id="13867" data-slide-title-pos="" data-slug="if-tv-characters-had-okcupid-profiles"> <header> <h1>If TV Characters Had OKCupid Profiles </h1> </header> <ol class="slides"> <li class="slide" data-content-source="Gallery - Image" data-id="52fe6338b589e4468e0003a4" data-skip-rerender="false" data-thumb="http://i.amz.mshcdn.com/QGIfugcpiYLwfKSH4hKcQGCKyK4=/180x140/http%3A%2F%2Fmashable.com%2Fwp-content%2Fgallery%2Fif-tv-characters-had-okcupid-profiles%2F131202_dating-profile-sherlock.jpg"> <figure> <img alt="" src="http://i.amz.mshcdn.com/ZdphYOCVJcOzveCdTGywssmFgmw=/fit-in/850x850/http%3A%2F%2Fmashable.com%2Fwp-content%2Fgallery%2Fif-tv-characters-had-okcupid-profiles%2F131202_dating-profile-sherlock.jpg"> </img></figure> <div class="meta"> <h2 class="title">1. Sherlock Holmes from <em>Sherlock</em> </h2> <div class="caption"></div> <div class="credit"> Image:  <a href="http://www.theconnectivist.com/" target="_blank">The Connectivist</a> </div> </div> </li> <li class="slide" data-content-source="Gallery - Image" data-id="52fe6338b589e4468e0003a5" data-skip-rerender="false" dat ...
#
#
#
#
# <html><head><div class="article-info"><span class="byline "><a href="/author/brittany-levine/"><img alt="2016%2f06%2f30%2f5d%2f201503300cheadshot_20.a69ac.90e1a" class="author_image" src="http://i.amz.mshcdn.com/95Eu81GF4vPHFeM2tKbV0_9VPvQ=/90x90/2016%2F06%2F30%2F5d%2F201503300cHeadshot_20.a69ac.90e1a.jpg"/></a><span class="author_name">By <a href="/author/brittany-levine/">Brittany Levine Beckman</a></span><time datetime="Sun, 16 Nov 2014 03:46:24 +0000">2014-11-16 03:46:24 UTC</time></span></div></head><body><h1 class="title">Indigenous rights protesters burn Australian flags during G20 Summit</h1><figure class="article-image"><img alt="A protester sets an Australian flag on fire." class="microcontent" data-fragment="lead-image" data-image="http://i.amz.mshcdn.com/F3
# <html><head><div class="article-info"><span class="byline "><a href="/author/vignesh-ramachandran/"><img alt="Default-m" class="author_image" src="http://i.amz.mshcdn.com/raEPzavg65Jzvjy-L4U699QBlmQ=/90x90/default-m.jpg"/></a><span class="author_name">By <a href="/author/vignesh-ramachandran/">Vignesh Ramachandran</a></span><time datetime="Fri, 30 Aug 2013 00:49:06 +0000">2013-08-30 00:49:06 UTC</time></span></div></head><body><h1 class="title">This Basketball Will Coach You With Audible Feedback</h1><figure class="article-image"></figure><article data-channel="sports"><section class="article-content"> <div class="shift-to-hero"><div class="content-mash-video" data-autoplay="" data-embedurl="http://mashable.com/videos/embed?video=xVnmo4vC&amp;player=offsite" data-labels='["basketball", "kickstarter", "newsy", "sensor", "sports", "tech"]' data-playlist="http://content.jwplatform.com/manifests/xVnmo4vC.m3u8" data-template="postlead" data-thumbnail="http://content.jwplatform.com/thumbs/xVnmo4vC.jpg" data-title="Smart Basketball Could Be Your New Coach" data-video="2630091127001"></div></div> <p>If you're looking to step up your basketball game, you can now consider swapping your regular ball for one packed with smart capabilities.</p> <p><a href="http://www.shootersrevolution.com/" target="_blank">Shooters Revolution</a> has designed the EVO ONE smart basketball, which looks like a regular ball but has micro-sensor technology. The ball's sensor serves as a coach to help you improve your shooting technique, as explained in the video above.</p> <div class="see-also"><p>See also: <a href="http://mashable.com/2012/06/07/youtube-epic-nba-dunks/">Posterized! YouTube's 12 Most Epic NBA Dunks</a></p></div> <p><img alt="EvoOneBasketball2" class="" data-fragment="m!e92d" data-image="http://i.amz.mshcdn.com/iNwCsVyp0cbLIV-pp_IGiyQh87c=/http%3A%2F%2Fmashable.com%2Fwp-content%2Fuploads%2F2013%2F08%2FEvoOneBasketball2.jpg" data-micro="1" src="http://i.amz.mshcdn.com/ZoT4qiRWoW0dF65zGBpHSjbHo4E=/fit-in/1200x9600/http%3A%2F%2Fmashable.com%2Fwp-content%2Fuploads%2F2013%2F08%2FEvoOneBasketball2.jpg"/></p> <p>Once you activate the basketball's micro-sensor, the technology can measure the backspin rate, axes and balance of the ball when you shoot it. The device's micro-speaker will emit audible feedback, if you achieve optimal backspin of plus-or-minus two revolutions per second. "Wobbly, slow, or unorthodox backspin is not reinforced through audible feedback," writes the company on its Kickstarter page.</p> <p>The battery-powered sensor is removable and the basketball can be used normally. Shooters Revolution says the EVO ONE ball satisfies regulation weight and size standards.</p> <p>The company, headed by former athletes, is trying to raise $45,000 <a href="http://www.kickstarter.com/projects/shootersrev/evo-onetm-sensorized-basketball-performance-techno" target="_blank">on Kickstarter</a> to finalize the EVO ONE's development. With 19 days left in the Kickstarter campaign at time of writing, backers had already pledged more than $22,400. A limited number of backers can get their own EVO ONE for $59. The ball comes in an array of sizes.</p> <p>What do you think about this smart basketball? Share your thoughts in the comments.</p> <p><em>Image: Shooters Revolution <a href="http://www.kickstarter.com/projects/shootersrev/evo-onetm-sensorized-basketball-performance-techno" target="_blank">via Kickstarter</a></em></p> </section></article><footer class="article-topics"> Topics: <a href="/category/basketball/">basketball</a>, <a href="/category/coach/">coach</a>, <a href="/category/health-fitness/">Health &amp; Fitness</a>, <a href="/category/kickstarter/">kickstarter</a>, <a href="/category/lifestyle/">Lifestyle</a>, <a href="/category/newsy/">Newsy</a>, <a href="/category/sports/">Sports</a> </footer></body></html>
#
#
#
#
#  The thin bar at the top of the screen indicates page load progress." src="http://i.amz.mshcdn.com/rXyfcGt8a0ZtQjHG9O80O_FX8uk=/fit-in/850x850/http%3A%2F%2Fmashable.com%2Fwp-content%2Fgallery%2Fhands-on-with-ios-7%2Fios7-27.png"> </img></figure> <div class="meta"> <h2 class="title">Searching and Loading a Page</h2> <div class="caption"> <p>Typing in a URL or string of text offers up real-time suggestions for an address or search query.</p> <p>The thin bar at the top of the screen indicates page load progress.</p> </div> <div class="credit"> </div> </div> </li> <li class="slide" data-content-source="Gallery - Image" data-id="524c70a412d2cd7caa00041e" data-skip-rerender="false" data-thumb="http://i.amz.mshcdn.com/qz2MBFzxeRYNxSYywAmLoB6bNFU=/180x140/http%3A%2F%2Fmashable.com%2Fwp-content%2Fgallery%2Fhands-on-with-ios-7%2Fios7-28.png"> <figure> <img alt="It's like Cover Flow, but vertical!" src="http://i.amz.mshcdn.com/jddDVA_pmUzvW9ZH0e8QqfXgu_Q=/fit-in/850x850/http%3A%2F%2Fmashable.com%2Fwp-content%2Fgallery%2Fhands-on-with-ios-7%2Fios7-28.png"> </img></figure> <div class="meta"> <h2 class="title">Tabs</h2> <div class="caption"><p>It's like Cover Flow, but vertical!</p></div> <div class="credit"> </div> </div> </li> <li class="slide" data-content-source="Gallery - Image" data-id="524c70a412d2cd7caa00041f" data-skip-rerender="false" data-thumb="http://i.amz.mshcdn.com/f455gjoiLlgIVzTwC5rJ5xScMJw=/180x140/http%3A%2F%2Fmashable.com%2Fwp-content%2Fgallery%2Fhands-on-with-ios-7%2Fios7-29.png"> <figure> <img alt="FaceTime can now do audio calls!" src="http://i.amz.mshcdn.com/zST0VWxvG407votuigp0jW5H8XA=/fit-in/850x850/http%3A%2F%2Fmashable.com%2Fwp-content%2Fgallery%2Fhands-on-with-ios-7%2Fios7-29.png"> </img></figure> <div class="meta"> <h2 class="title">FaceTime Audio</h2> <div class="caption"><p>FaceTime can now do audio calls! </p></div> <div class="credit"> </div> </div> </li> </ol> </section> <p><em>Image: Apple</em></p> </section></article><footer class="article-topics"> Topics: <a href="/category/apple/">Apple</a>, <a href="/category/apps-software/">Apps and Software</a>, <a href="/category/backup/">backup</a>, <a href="/category/icloud/">iCloud</a>, <a href="/category/ios-7/">iOS 7</a>, <a href="/category/iphone/">iPhone</a>, <a href="/category/mobile/">Mobile</a>, <a href="/category/tech/">Tech</a> </footer></body></html> for Safari is texture free but full of color.%2Fwp-content%2Fgallery%2Fhands-on-with-ios-7%2Fios7-30.png"> <figure> <img alt="The calendar is de-leathered and has a very Google+ look." src="http://i.amz.mshcdn.com/C6s305S3_7PL7vcVeyc5lIk5R0o=/fit-in/850x850/http%3A%2F%2Fmashable.com%2Fwp-content%2Fgallery%2Fhands-on-with-ios-7%2Fios7-30.png"> </img></figure> <div class="meta"> <h2 class="title">Calendar</h2> <div class="caption"><p>The calendar is de-leathered and has a very Google+ look.</p></div> <div class="credit"> </div> </div> </li> <li class="slide" data-content-source="Gallery - Image" data-id="524c70a412d2cd7caa000416" data-skip-rerender="false" data-thumb="http://i.amz.mshcdn.com/hHT6CdISROPJTU2ULMMpx2TaLiE=/180x140/http%3A%2F%2Fmashable.com%2Fwp-content%2Fgallery%2Fhands-on-with-ios-7%2Fios7-31.png"> <figure> <img alt="The calendar gets a proper inbox for incoming invitations." src="http://i.amz.mshcdn.com/gO1c5wh-qzz7RaAjsO1klwujEv4=/fit-in/850x850/http%3A%2F%2Fmashable.com%2Fwp-content%2Fgallery%2Fhands-on-with-ios-7%2Fios7-31.png"> </img></figure> <div class="meta"> <h2 class="title">Calendar Inbox</h2> <div class="caption"><p>The calendar gets a proper inbox for incoming invitations.</p></div> <div class="credit"> </div> </div> </li> <li class="slide" data-content-source="Gallery - Image" data-id="524c70a412d2cd7caa000417" data-skip-rerender="false" data-thumb="http://i.amz.mshcdn.com/8DKqOF_w_9eDxcTFCFugvfiuLkk=/180x140/http%3A%2F%2Fmashable.com%2Fwp-content%2Fgallery%2Fhands-on-with-ios-7%2Fios7-21.png"> <figure> <img alt="Apple Maps has toned down some of its textures but the basic app lo ...

# %%
for c in pop_group.get_group(-1).sample(n=5, random_state=1)['content']:
    print(c)
    print('\n\n\n')
# Out:
# <html><head><div class="article-info"><span class="byline basic"><span class="author_name">By <a href="/author/colin-gorenstein/">Colin Gorenstein</a></span><time datetime="Tue, 30 Sep 2014 16:50:49 +0000">2014-09-30 16:50:49 UTC</time></span></div></head><body><h1 class="title">Mindy Kaling and Elmo Are Undeniably Enthusiastic</h1><figure class="article-image"></figure><article data-channel="watercooler"><section class="article-content viral-video"> <div class="viral-video-lead"> <p><iframe allowfullscreen="" frameborder="0" height="360" src="https://www.youtube.com/embed/em5SSa-IVUU?enablejsapi=1&amp;" width="640"></iframe></p> <script src="http://a.amz.mshcdn.com/assets/lib/aab-7ce243b38b9cc2caec816aff811d3153.js" type="text/javascript"></script> </div> <p>Elmo is really enthusiastic about dancing with friends. <a href="http://mashable.com/category/mindy-kaling/">Mindy Kaling</a> is really enthusiastic about dancing with chickens. Chickens are, evidently, really enthusiastic about jumping.</p> <p>The crew has to meet somewhere in the middle, so the final compromise is to jump to music. </p> <p>For anyone who's dreamed of a dance party filled with chickens and Mindy Kaling (really, who hasn't?), your moment has come.</p> <figure class="image"><p><img alt="mindy2" class="fullwidth" data-caption="" data-credit-link="" data-credit-name="" data-credit-provider="Youtube" data-fragment="m!e10a" data-image="http://i.amz.mshcdn.com/Ed7F5KCsWgoMVwrXzm7R3zGAhjE=/http%3A%2F%2Fmashable.com%2Fwp-content%2Fuploads%2F2014%2F09%2Fmindy2.gif" data-micro="1" src="http://i.amz.mshcdn.com/Vr_q8TL7w7dqFX_Wq3nNYrc_dqo=/fit-in/1200x9600/http%3A%2F%2Fmashable.com%2Fwp-content%2Fuploads%2F2014%2F09%2Fmindy2.gif" title="mindy2"/></p> <div class="image-credit"></div></figure><fig
image-credit">Image:  SteelSeries</div></figure><article data-channel="gaming"><section class="article-content"> <p>To the top video-game players on the planet, fates are decided in hundredths of a second. Faster reaction time can mean the difference between finishing a level in record time, or ending up as someone's fragged lunch.</p> <p>The SteelSeries Sentry, announced Monday at <a href="http://mashable.com/category/e3/">E3</a>, introduces players to a new way to improve their game: <a href="http://mashable.com/category/eye-tracking/">eye tracking</a>. The product is a ruler-shaped sensor that connects to a PC's USB port, and tracks a user's eye movements. For gamers, this means they can analyze what they're looking at on the screen, for how long, and how often their gaze changes.</p> <div class="see-also"><p>See also: <a href="http://mashable.com/2011/06/05/android-multiplayer-games/">10 Great Android Multiplayer Games</a></p></div> <p>That last statistic, called fixations per minute (FPM), is vitally important. With the data, a serious gamer can draw correlations to actions per minute (APM). SteelSeries said it is working with some of the best gamers on the planet to establish "peak performance goals." Generally, a low FPM indicates the gamer can process a lot of information, according to the company.</p> <p><iframe allowfullscreen="" frameborder="0" height="315" src="//www.youtube.com/embed/Ho5lWs6ld3Q?enablejsapi=1&amp;" width="560"></iframe></p> <p>The Sentry is the first commercial product to result from a <a href="http://mashable.com/2014/01/02/tobii-eye-controller-gaming/">partnership</a> between SteelSeries and <a href="http://mashable.com/category/tobii/">Tobii</a>, which builds the eye-tracking technology. Although the Sentry's initial thrust will be as a training and analytics device, Tobii said it will be capable of tracking eye movement for actual gameplay in the future.</p> <p>The two companies are working with developers to build in support for eye tracking on some titles, and they're working with a third company, <a href="http://www.overwolf.com/" target="_blank">Overwolf</a>, to add social-media interaction. "Staring down" your opponent may have a whole new meaning once the Sentry really gets cooking.</p> <p>There is currently no price or release date for the Sentry yet, though Tobii said it will be available "later this year." Its <a href="http://steelseries.com/steelseries-sentry-eye-tracker" target="_blank">product page</a> lets interested buyers sign up to be notified when the Sentry is available.</p> </section></article><footer class="article-topics"> Topics: <a href="/category/eye-tracking/">eye tracking</a>, <a href="/category/gadgets/">Gadgets</a>, <a href="/category/gaming/">Gaming</a>, <a ...

# %% [markdown]
# ## Get published date

# %%
def get_public_datetime(content):
    """
    input: raw content
    output: article published time
    """
    soup = BeautifulSoup(content, 'html.parser')
    
    t = soup.time
    dt = datetime.strptime(t['datetime'], '%a, %d %b %Y %H:%M:%S %z')
    
    return dt

# %%
def populate_public_time_data(df):
    start = timeit.default_timer()
    
    for idx, r in df.iterrows():
        dt = get_public_datetime(r['content'])

        df.loc[idx, 'p_year'] = dt.year
        df.loc[idx, 'p_month'] = dt.month
        df.loc[idx, 'p_day'] = dt.day
        df.loc[idx, 'p_hour'] = dt.hour
        df.loc[idx, 'p_minute'] = dt.minute
        df.loc[idx, 'p_second'] = dt.second
        df.loc[idx, 'p_weekday'] = dt.weekday()
    
    stop = timeit.default_timer()
    print('Time: ', stop - start)  
    
    display(df.head())
    display(df.isna().sum())

# %%
populate_public_time_data(df_train)
# Out:
# Time:  184.87019739102107
#    id  pop                                            content  p_year  \
# 0   0   -1  <html><head><div class="article-info"> <span c...  2013.0
# 1   1    1  <html><head><div class="article-info"><span cl...  2013.0
# 2   2    1  <html><head><div class="article-info"><span cl...  2014.0
# 3   3   -1  <html><head><div class="article-info"><span cl...  2013.0
# 4   4   -1  <html><head><div class="article-info"><span cl...  2014.0
#
#    p_month  p_day  p_hour  p_minute  p_second  p_weekday
# 0      6.0   19.0    15.0       4.0      30.0        2.0
# 1      3.0   28.0    17.0      40.0      55.0        3.0
# 2      5.0    7.0    19.0      15.0      20.0        2.0
# 3     10.0   11.0     2.0      26.0      50.0        4.0
# 4      4.0   17.0     3.0      31.0      43.0        3.0
# id           0
# pop          0
# content      0
# p_year       0
# p_month      0
# p_day        0
# p_hour       0
# p_minute     0
# p_second     0
# p_weekday    0
# dtype: int64

# %%
populate_public_time_data(df_sample)
# Out:
# Time:  6.301303349959198
#           id  pop                                            content  p_year  \
# 13516  13516   -1  <html><head><div class="article-info"><span cl...  2014.0
# 11607  11607   -1  <html><head><div class="article-info"><span cl...  2014.0
# 11866  11866    1  <html><head><div class="article-info"><span cl...  2013.0
# 25540  25540   -1  <html><head><div class="article-info"><span cl...  2013.0
# 26611  26611   -1  <html><head><div class="article-info"><span cl...  2014.0
#
#        p_month  p_day  p_hour  p_minute  p_second  p_weekday
# 13516      8.0    4.0    16.0      14.0      55.0        0.0
# 11607      2.0   20.0     9.0      24.0      23.0        3.0
# 11866      4.0   24.0    17.0      43.0      38.0        2.0
# 25540     10.0   22.0    15.0      30.0      17.0        1.0
# 26611      1.0    6.0    20.0      39.0      46.0        0.0
# id           0
# pop          0
# content      0
# p_year       0
# p_month      0
# p_day        0
# p_hour       0
# p_minute     0
# p_second     0
# p_weekday    0
# dtype: int64

# %% [markdown]
# ## Find all tags & get useful tag number

# %%
def get_all_tag(content):
    soup = BeautifulSoup(content, 'html.parser')
    
    tags = set()
    for tag in soup.find_all():
        tags.add(tag.name)
        
    return tags

# %%
def get_all_df_tag(df):
    tags = set()
    
    start = timeit.default_timer()
    
    for idx, r in df.iterrows():
        tags = tags.union(get_all_tag(r['content']))
        
    stop = timeit.default_timer()
    print('Time: ', stop - start)
        
    return tags

# %%
all_tags = get_all_df_tag(df_sample)
all_tags

# %%
all_tags
# Out:
# {'a',
#  'article',
#  'b',
#  'blockquote',
#  'body',
#  'br',
#  'center',
#  'del',
#  'div',
#  'div-class',
#  'divclass',
#  'em',
#  'embed',
#  'en',
#  'figcaption',
#  'figure',
#  'footer',
#  'glowinggoodies',
#  'h1',
#  'h2',
#  'h3',
#  'head',
#  'header',
#  'hr',
#  'html',
#  'i',
#  'iframe',
#  'img',
#  'li',
#  'link',
#  'noscript',
#  'object',
#  'ol',
#  'p',
#  'param',
#  'script',
#  'section',
#  'small',
#  'span',
#  'strong',
#  'style',
#  'sub',
#  'time',
#  'ul'}

# %%
def get_tag_num(content, tag):
    """
    input: raw content
    output: tag numbers
    """
    start = timeit.default_timer()
    
    soup = BeautifulSoup(content, 'html.parser')
    
    return len(soup.find_all(tag))

# %%
start = timeit.default_timer()

useful_tags = [
    'blockquote',
    'figcaption',
    'figure',
    'h1', 
    'h2',
    'h3',
    'iframe',
    'img',
    'strong'
]

for idx, r in df_sample.iterrows():
    for tag in useful_tags:
        col = 'num_tag_{}'.format(tag)
        df_sample.loc[idx, col] = get_tag_num(r['content'], tag)
    
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# Time:  39.66087353701005

# %% [markdown]
# ## Get title of news

# %%
# def get_title(content):
#     soup = BeautifulSoup(content, 'html.parser')
#     return soup.h1.string

# %%
# df_sample['title'] = df_sample['content'].progress_apply(get_title)
# Out:
# 100%|██████████| 1000/1000 [00:04<00:00, 234.43it/s]

# %%
# df_train['title'] = df_train['content'].progress_apply(get_title)
# Out:
# 100%|██████████| 27643/27643 [02:02<00:00, 226.20it/s]

# %%
def get_title_pos_tag(title):
    tag_pair = pos_tag(word_tokenize(clean_text(title)))
    tags = ""
    
    for s, tag in tag_pair:
        tags += tag + ' '
    return tags

# %%
df_train['title_pos_tag_seq'] = df_train['title'].progress_apply(get_title_pos_tag)
df_test['title_pos_tag_seq'] = df_test['title'].progress_apply(get_title_pos_tag)

# %%
def get_title_pos_tag_cols(df):
    def fill(arr, i):
        try:
            return arr[i]
        except:
            return 'NONE'
        
    start = timeit.default_timer()
    
#     df['title_pos_tag_arr'] =  df['title'].apply(lambda t: get_title_pos_tag(t).split()) 
    df['title_pos_tag_arr'] =  df['title_pos_tag_seq'].apply(lambda seq: seq.split())
    df['title_len'] =  df['title_pos_tag_seq'].apply(lambda seq: len(seq.split()))
    MAX_LEN = 15
        
    for i in range(MAX_LEN):
        col_name = 'title_pos_tag_{}'.format(i+1)
        df[col_name] = df['title_pos_tag_arr'].apply(lambda arr: fill(arr, i))

    stop = timeit.default_timer()
    print('Time: ', stop - start)  
    
    display(df.head())
    display(df.isna().sum())

# %%
get_title_pos_tag_cols(df_train)
get_title_pos_tag_cols(df_test)
# Out:
# Time:  0.1642745
#    Id  Popularity                                       Page content  \
# 0   0          -1  <html><head><div class="article-info"> <span c...
# 1   1           1  <html><head><div class="article-info"><span cl...
# 2   2           1  <html><head><div class="article-info"><span cl...
# 3   3          -1  <html><head><div class="article-info"><span cl...
# 4   4          -1  <html><head><div class="article-info"><span cl...
#
#                                              article  \
# 0  There may be killer asteroids headed for Earth...
# 1  Google took a stand of sorts against patent-la...
# 2  You've spend countless hours training to be an...
# 3   Tired of the same old sports fails and news f...
# 4  At 6-foot-5 and 298 pounds, All-Pro NFL star J...
#
#                                                title  \
# 0  NASA's Grand Challenge: Stop Asteroids From De...
# 1  Google's New Open Source Patent Pledge: We Won...
# 2  Ballin': 2014 NFL Draft Picks Get to Choose Th...
# 3        Cameraperson Fails Deliver Slapstick Laughs
# 4  NFL Star Helps Young Fan Prove Friendship With...
#
#                                               topics   data_channel  see_also  \
# 0  ['Asteroid', 'Asteroids', 'challenge', 'Earth'...          world         1
# 1  ['Apps and Software', 'Google', 'open source',...           tech         1
# 2  ['Entertainment', 'NFL', 'NFL Draft', 'Sports'...  entertainment         1
# 3       ['Sports', 'Video', 'Videos', 'Watercooler']    watercooler         1
# 4  ['Entertainment', 'instagram', 'instagram vide...  entertainment         1
#
#    p_year  p_month  ...  title_pos_tag_6  title_pos_tag_7  title_pos_tag_8  \
# 0  2013.0      6.0  ...               NN               IN              VBG
# 1  2013.0      3.0  ...               NN               NN              PRP
# 2  2014.0      5.0  ...              VBP               TO               VB
# 3  2013.0     10.0  ...             NONE             NONE             NONE
# 4  2014.0      4.0  ...               VB               NN               IN
#
#    title_pos_tag_9  title_pos_tag_10 title_pos_tag_11  title_pos_tag_12  \
# 0               NN              NONE             NONE              NONE
# 1               MD                RB               VB                IN
# 2             PRP$                JJ               NN                NN
# 3             NONE              NONE             NONE              NONE
# 4               JJ                NN             NONE              NONE
#
#    title_pos_tag_13  title_pos_tag_14 title_pos_tag_15
# 0              NONE              NONE             NONE
# 1               VBN                RB             NONE
# 2              NONE              NONE             NONE
# 3              NONE              NONE             NONE
# 4              NONE              NONE             NONE
#
# [5 rows x 37 columns]
# Id                   0
# Popularity           0
# Page content         0
# article              0
# title                0
# topics               0
# data_channel         0
# see_also             0
# p_year               0
# p_month              0
# p_day                0
# p_hour               0
# p_minute             0
# p_second             0
# p_weekday            0
# author               0
# author scalar        0
# img_num              0
# link_num             0
# title_pos_tag_seq    0
# title_pos_tag_arr    0
# title_len            0
# title_pos_tag_1      0
# title_pos_tag_2      0
# title_pos_tag_3      0
# title_pos_tag_4      0
# title_pos_tag_5      0
# title_pos_tag_6      0
# title_pos_tag_7      0
# title_pos_tag_8      0
# title_pos_tag_9      0
# title_pos_tag_10     0
# title_pos_tag_11     0
# title_pos_tag_12     0
# title_pos_tag_13     0
# title_pos_tag_14     0
# title_pos_tag_15     0
# dtype: int64
# Time:  0.105737
#       Id                                       Page content  \
# 0  27643  <html><head><div class="article-info"><span cl...
# 1  27644  <html><head><div class="article-info"><span cl...
# 2  27645  <html><head><div class="article-info"><span cl...
# 3  27646  <html><head><div class="article-info"><span cl...
# 4  27647  <html><head><div class="article-info"><span cl...
#
#                                              article  \
# 0   Note to humanity: One Direction fandom ain't ...
# 1  Shortly after announcing a hardware upgrade fo...
# 2  Well, that was quick. Just hours after going o...
# 3   Between Two Ferns: Oscar Buzz Edition Part 1 ...
# 4   Ever since The Hurt Locker it seems like we h...
#
#                                                title  \
# 0  Soccer Star Gets Twitter Death Threats After T...
# 1               Google Glass Gets an Accessory Store
# 2     OUYA Gaming Console Already Sold Out on Amazon
# 3           'Between Two Ferns' Mocks Oscar Nominees
# 4  'American Sniper' Trailer: Looks Like Eastwood...
#
#                                               topics   data_channel  see_also  \
# 0  ['Entertainment', 'Music', 'One Direction', 's...  entertainment         1
# 1  ['Gadgets', 'glass', 'Google', 'Google Glass',...           tech         1
# 2  ['amazon', 'amazon kindle', 'Business', 'Gaming']       business         1
# 3  ['Between Two Ferns', 'Movies', 'The Oscars', ...           film         1
# 4  ['American Sniper', 'Awards', 'Bradley Cooper'...  entertainment         1
#
#    p_year  p_month  p_day  ...  title_pos_tag_6  title_pos_tag_7  \
# 0  2013.0      9.0    9.0  ...              NNS               IN
# 1  2013.0     10.0   31.0  ...               NN             NONE
# 2  2013.0      6.0   25.0  ...               RP               IN
# 3  2013.0      2.0   13.0  ...              VBP              NNS
# 4  2014.0     10.0    3.0  ...               IN               NN
#
#    title_pos_tag_8  title_pos_tag_9 title_pos_tag_10  title_pos_tag_11  \
# 0              VBG               CD               NN                NN
# 1             NONE             NONE             NONE              NONE
# 2               NN             NONE             NONE              NONE
# 3             NONE             NONE             NONE              NONE
# 4               MD               VB               RB                IN
#
#    title_pos_tag_12  title_pos_tag_13 title_pos_tag_14 title_pos_tag_15
# 0              NONE              NONE             NONE             NONE
# 1              NONE              NONE             NONE             NONE
# 2              NONE              NONE             NONE             NONE
# 3              NONE              NONE             NONE             NONE
# 4                DT                NN             NONE             NONE
#
# [5 rows x 36 columns]
# Id                   0
# Page content         0
# article              1
# title                0
# topics               0
# data_channel         0
# see_also             0
# p_year               1
# p_month              1
# p_day                1
# p_hour               1
# p_minute             1
# p_second             1
# p_weekday            1
# author               0
# author_scalar        0
# img_num              0
# link_num             0
# title_pos_tag_seq    0
# title_pos_tag_arr    0
# title_len            0
# title_pos_tag_1      0
# title_pos_tag_2      0
# title_pos_tag_3      0
# title_pos_tag_4      0
# title_pos_tag_5      0
# title_pos_tag_6      0
# title_pos_tag_7      0
# title_pos_tag_8      0
# title_pos_tag_9      0
# title_pos_tag_10     0
# title_pos_tag_11     0
# title_pos_tag_12     0
# title_pos_tag_13     0
# title_pos_tag_14     0
# title_pos_tag_15     0
# dtype: int64

# %%
df_train['num_topics'] = df_train['topics'].apply(lambda arr: len(arr))
df_test['num_topics'] = df_test['topics'].apply(lambda arr: len(arr))

# %%
df_test.drop(['title_pos_tag_arr'], axis=1, inplace=True)

# %% [markdown]
# ## Get first paragraph

# %%
def get_paragraph(content, idx):
    soup = BeautifulSoup(content, 'html.parser')
    all_p = soup.find_all('p')
    p_idx = 0
    res = ""
    
    for i in range(idx):
        try:
            p = all_p[p_idx].getText().lower()
            if 'see also' in p:
                p_idx += 1
                p = all_p[p_idx].getText().lower()
                res += ' ' + p
            else:
                res += ' ' + p
        except:
            res += ""
            
        p_idx += 1
        
    return res

# %%
df_train['para_1_3'] = df_train['content'].progress_apply(lambda c: get_paragraph(c, 3))
df_test['para_1_3'] = df_test['content'].progress_apply(lambda c: get_paragraph(c, 3))

# %%
df_train['para_1_3_len'] = df_train['para_1_3'].progress_apply(lambda s: len(preprocessor(s).split()))
df_test['para_1_3_len'] = df_test['para_1_3'].progress_apply(lambda s: len(preprocessor(s).split()))

# %%
df_train['article_len'] = df_train['article'].progress_apply(lambda s: s.split())
df_test['article_len'] = df_test['article'].progress_apply(lambda s: s.split())
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 27643/27643 [00:01<00:00, 24968.33it/s]
#  39%|████████████████████████████▋                                             | 4601/11847 [00:00<00:00, 23640.60it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-bef77f96a78d> in <module>
#       1 df_train['article_len'] = df_train['article'].progress_apply(lambda s: s.split())
# ----> 2 df_test['article_len'] = df_test['article'].progress_apply(lambda s: s.split())
#
# ~\Anaconda3\lib\site-packages\tqdm\_tqdm.py in inner(df, func, *args, **kwargs)
#     677                 # Apply the provided function (in **kwargs)
#     678                 # on the df using our wrapper (which provides bar updating)
# --> 679                 result = getattr(df, df_function)(wrapper, **kwargs)
#     680
#     681                 # Close bar and return pandas calculation result
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\Anaconda3\lib\site-packages\tqdm\_tqdm.py in wrapper(*args, **kwargs)
#     673                     # take a fast or slow code path; so stop when t.total==t.n
#     674                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 675                     return func(*args, **kwargs)
#     676
#     677                 # Apply the provided function (in **kwargs)
#
# <ipython-input-29-bef77f96a78d> in <lambda>(s)
#       1 df_train['article_len'] = df_train['article'].progress_apply(lambda s: s.split())
# ----> 2 df_test['article_len'] = df_test['article'].progress_apply(lambda s: s.split())
#
# AttributeError: 'int' object has no attribute 'split'

# %% [markdown]
# ## tokenize words

# %%
count_topics = CountVectorizer(
    ngram_range=(1, 1),
    preprocessor=preprocessor,
#     max_features=100
)

doc_bag = count_topics.fit_transform(df_train['para_1'])

# %%
len(count_topics.get_feature_names())
# Out:
# 25618

# %%
tfidf_topics = TfidfVectorizer(
    ngram_range=(1, 2),
    preprocessor=preprocessor,
    max_features=100
)

doc_tfidf = tfidf_topics.fit_transform(df_train['para_1'])

# %%
tfidf_topics.get_feature_names()
# Out:
# ['accord',
#  'also',
#  'announc',
#  'app',
#  'appl',
#  'around',
#  'back',
#  'big',
#  'busi',
#  'call',
#  'citi',
#  'come',
#  'compani',
#  'could',
#  'day',
#  'devic',
#  'digit',
#  'even',
#  'event',
#  'facebook',
#  'featur',
#  'final',
#  'find',
#  'first',
#  'friday',
#  'game',
#  'get',
#  'go',
#  'good',
#  'googl',
#  'help',
#  'internet',
#  'iphon',
#  'job',
#  'know',
#  'last',
#  'launch',
#  'like',
#  'live',
#  'look',
#  'made',
#  'make',
#  'mani',
#  'market',
#  'mashabl',
#  'may',
#  'media',
#  'might',
#  'million',
#  'mobil',
#  'monday',
#  'month',
#  'much',
#  'network',
#  'new',
#  'new york',
#  'news',
#  'next',
#  'night',
#  'one',
#  'onlin',
#  'peopl',
#  'phone',
#  'photo',
#  'releas',
#  'report',
#  'said',
#  'say',
#  'see',
#  'seri',
#  'servic',
#  'show',
#  'sinc',
#  'smartphon',
#  'social',
#  'space',
#  'start',
#  'state',
#  'take',
#  'technolog',
#  'thing',
#  'thursday',
#  'time',
#  'tuesday',
#  'twitter',
#  'two',
#  'updat',
#  'us',
#  'use',
#  'user',
#  'video',
#  'want',
#  'way',
#  'wednesday',
#  'week',
#  'work',
#  'world',
#  'would',
#  'year',
#  'york']

# %% [markdown]
# ## Prepare pipeline

# %%
# df = pd.concat([df_train, df_train_oh_dc], axis=1)
df_sample = df_train.sample(n=2000, random_state=4)
df_sample.reset_index(inplace=True)
X = df_sample.drop(['pop'], axis=1)
y = df_sample['pop']

# X = df_train.drop(['pop'], axis=1)
# y = df_train['pop']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)

# %%
TITLE_MAX_LEN = 15
title_pos_tag_col = ['title_pos_tag_{}'.format(i+1) for i in range(TITLE_MAX_LEN)]

all_pos_tag = set()

for col in df_train[title_pos_tag_col]:
    all_pos_tag = all_pos_tag.union(df_train[col].unique())

# %%
class TitlePosTagEncodeTransformer():
    def __init__(self):
        self.le = LabelEncoder()
        self.le.fit(list(all_pos_tag))

    def transform(self, df, **transform_params):
        for col in df[title_pos_tag_col]:
            df[col] = self.le.transform(df[col])
        
        return df

    def fit(self, X, y=None, **fit_params):
        return self
    
    def get_params(self, deep=True):
        return {}

# %%
names = []
pipes = []
TITLE_MAX_LEN = 5

date_col = ['p_year', 'p_month', 'p_day', 'p_hour', 'p_weekday']
used_col = ['author_scalar', 'num_topics', 'title_len', 'img_num', 'see_also']
title_pos_tag_col = ['title_pos_tag_{}'.format(i+1) for i in range(TITLE_MAX_LEN)]

topic_bow_vec = CountVectorizer(
    ngram_range=(1, 2), 
    preprocessor=preprocessor, 
    max_features=6000
)

title_bow_vec = CountVectorizer(
    ngram_range=(1, 2), 
    preprocessor=preprocessor, 
    max_features=4000
)

article_tfidf_vec = TfidfVectorizer(
    ngram_range=(1, 2), 
    preprocessor=preprocessor, 
    max_features=3000
)

pca_50 = TruncatedSVD(
    n_components=30,
    random_state=0
)

pca_300 = TruncatedSVD(
    n_components=300,
    random_state=0
)

data_channel_one_hot = OneHotEncoder(handle_unknown='ignore')
std_scaler = StandardScaler()
poly_scaler = PolynomialFeatures(2, include_bias=False)
title_pos_tag_trans = TitlePosTagEncodeTransformer()

p1 = Pipeline([
    ('colt', make_column_transformer(
            (data_channel_one_hot, ['data_channel']),
            (std_scaler, date_col+used_col),
            (poly_scaler, date_col+used_col),
            (title_pos_tag_trans, title_pos_tag_col)
    )),
#     ('pca', pca_50),
    ('clf', RidgeClassifier(alpha=10, normalize=True))
])
names.append('Ridge')
pipes.append(p1)

# p2 = Pipeline([
#     ('colt', make_column_transformer(
#             (data_channel_one_hot, ['data_channel']),
#             (std_scaler, date_col+used_col),
#             (poly_scaler, date_col+used_col),
#             (title_pos_tag_trans, title_pos_tag_col)
#     )),
#     ("clf", KNeighborsClassifier(n_neighbors = 100, p = 2))
# ]
# # , verbose=True
# )
# names.append('KNN')
# pipes.append(p2)

# p3 = Pipeline([
#     ('colt', make_column_transformer(
#             (topic_bow_vec, 'topics'),
#             (title_bow_vec, 'title'),
#             (para_tfidf_vec, 'para_1_3'),
#             (data_channel_one_hot, ['data_channel']),
#             (std_scaler, date_col+used_col),
#             (poly_scaler, date_col+used_col),
#             (title_pos_tag_trans, title_pos_tag_col)
#     )),
#     ('clf', SVC(kernel = "linear", random_state = 0, gamma = 0.001, C = 100.0))
# ]
# , verbose=True
# )
# names.append('SVC')
# pipes.append(p3)

# ada_clf = DecisionTreeClassifier(max_depth=1)
# p4 = Pipeline([
#     ('colt', make_column_transformer(
#             (topic_bow_vec, 'topics'),
#             (title_bow_vec, 'title'),
#             (para_tfidf_vec, 'para_1_3'),
#             (data_channel_one_hot, ['data_channel']),
#             (std_scaler, date_col+used_col),
#             (poly_scaler, date_col+used_col),
#             (title_pos_tag_trans, title_pos_tag_col)
#     )),
# #     ('pca', pca_300),
#     ('clf', AdaBoostClassifier(ada_clf, n_estimators=500, random_state=0, learning_rate=0.1))
# ]
# , verbose=True
# )
# names.append('Ada')
# pipes.append(p4)

bag_clf = DecisionTreeClassifier(max_depth=1)
p5 = Pipeline([
    ('colt', make_column_transformer(
            (topic_bow_vec, 'topics'),
            (title_bow_vec, 'title'),
#             (para_tfidf_vec, 'para_1_3'),
            (article_tfidf_vec, 'article'),
            (data_channel_one_hot, ['data_channel']),
            (std_scaler, date_col+used_col),
            (poly_scaler, date_col+used_col),
            (title_pos_tag_trans, title_pos_tag_col)
    )),
    ('clf', BaggingClassifier(
            base_estimator=bag_clf, 
            n_estimators=500, 
            max_samples=0.7,
            n_jobs=8, 
            random_state=0
    ))
]
, verbose=True
)
names.append('Bag')
pipes.append(p5)

#     ("clf", KNeighborsClassifier(n_neighbors = 30, p = 2))
#     ('dt', DecisionTreeClassifier(random_state=0))
#     ('gnb', GaussianNB())
#     ('mnb', MultinomialNB())
#     ('clf', RidgeClassifier(alpha=10, normalize=True))
#     ('clf', LogisticRegression(solver = "liblinear"))

# %%
# p3.fit(X_train, y_train)

# %%
# from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB, ComplementNB

# %%
# CV
K = 10
start = timeit.default_timer()

print('[auc (5-fold cv)]')
for name, clf in zip(names, pipes):
    scores = cross_val_score(
        estimator=clf, 
        X=X_train, 
        y=y_train,
        cv=K, 
        scoring='roc_auc'
    )
    print('%s: %.3f (+/-%.3f)' % (name, scores.mean(), scores.std()))
    
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# [auc (5-fold cv)]
# Ridge: 0.584 (+/-0.025)
# Bag: 0.561 (+/-0.038)
# Time:  152.7318801

# %%
def fit_multiple_estimators(classifiers, X_list, y, sample_weights = None):

    # Convert the labels `y` using LabelEncoder, because the predict method is using index-based pointers
    # which will be converted back to original data later.
    le_ = LabelEncoder()
    le_.fit(y)
    transformed_y = le_.transform(y)

    # Fit all estimators with their respective feature arrays
    estimators_ = [clf.fit(X, y) if sample_weights is None \
           else clf.fit(X, y, sample_weights) \
           for clf, X in zip([clf for _, clf in classifiers], X_list)]

    return estimators_, le_


def predict_from_multiple_estimator(estimators, label_encoder, X_list, weights = None):

    # Predict 'soft' voting with probabilities

    pred1 = np.asarray([clf.predict_proba(X) for clf, X in zip(estimators, X_list)])
    pred2 = np.average(pred1, axis=0, weights=weights)
    pred = np.argmax(pred2, axis=1)

    # Convert integer predictions to original labels:
    return label_encoder.inverse_transform(pred)

# %%
# Voting
print('[Voting]')
K = 10

weights = list(itertools.permutations(range(0,3)))
# weights = [
#     (1, 0, 0),
#     (4, 0, 1),
#     (4, 1, 0),
#     (9, 0, 1),
#     (9, 1, 0)
# ]
# weights = [
#     (1, 0),
#     (0, 1),
#     (1, 1),
#     (2, 1),
#     (1, 2),
#     (3, 1),
#     (1, 3),
#     (3, 2),
#     (2, 3),
# ]

best_vt, best_w, best_score = None, (), -1
for weight in weights:
    l_weight = list(weight)
    kf = KFold(n_splits=K, random_state=0)
    
    scores = []
    for train_index, test_index in kf.split(df_sample):

        X_train, X_test = X.loc[train_index], X.loc[test_index]
        y_train, y_test = y.loc[train_index], y.loc[test_index]
    
        y_preds = []
        for clf in pipes:
            clf.fit(X_train, y_train)
            
            try:
                y_pred = clf.predict_proba(X_test).T[1]
            except:
                d = clf.decision_function(X_test)
                y_pred = np.exp(d) / (1 + np.exp(d))
            
            y_preds.append(y_pred)
        
        y_pred = np.dot(np.transpose(y_preds), l_weight)
            
        score = roc_auc_score(y_test, y_pred)
        scores.append(score)
        
    mean = np.mean(scores)
    std = np.std(scores)
    print('%s: %.3f (+/- %.3f)' % (weight, mean, std))
    if best_score < mean:
        best_vt, best_w, best_score = clf, weight, mean

print('\nBest %s: %.3f' % (best_w, best_score))
# Out:
# [Voting]
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   1.9s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# (0, 1, 2): 0.528 (+/- 0.075)
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# (0, 2, 1): 0.527 (+/- 0.076)
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   1.9s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# (1, 0, 2): 0.553 (+/- 0.040)
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   1.9s
# (1, 2, 0): 0.530 (+/- 0.076)
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   1.9s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   1.9s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# (2, 0, 1): 0.556 (+/- 0.047)
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   1.9s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=   2.0s
# (2, 1, 0): 0.541 (+/- 0.071)
#
# Best (2, 0, 1): 0.556

# %%
p5.fit(X_train, y_train)

try:
    d = p5.decision_function(X_test)
    y_pred = np.exp(d) / (1 + np.exp(d))
except:
    y_pred = p5.predict_proba(X_test).T[1]

roc_auc_score(y_test, y_pred)
# Out:
# [Pipeline] .............. (step 1 of 2) Processing colt, total=   5.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  13.9s
# 0.5846540632777883

# %% [markdown]
# ## Generate prediction

# %%
X = df_train.drop(['pop'], axis=1)
y = df_train['pop']

# %%
df_f_test = pd.DataFrame(df_test, columns=X.columns)

# %%
X.shape
# Out:
# (27643, 39)

# %%
df_f_test.shape
# Out:
# (11847, 39)

# %%
p1.fit(X, y)
p4.fit(X, y)

d = p1.decision_function(df_f_test)
y_pred_1 = np.exp(d) / (1 + np.exp(d))

y_pred_4 = p4.predict_proba(df_f_test).T[1]

y_pred = y_pred_1 * 0.5 + y_pred_4 * 0.5
# Out:
# [Pipeline] .............. (step 1 of 2) Processing colt, total=  44.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 2.3min

# %%
df_sub = pd.read_csv(p_sub)
df_sub['Popularity'] = y_pred
df_sub.head()
# Out:
#       Id  Popularity
# 0  27643    0.464656
# 1  27644    0.479776
# 2  27645    0.475722
# 3  27646    0.485299
# 4  27647    0.512926

# %%
df_sub = pd.read_csv(p_sub)
df_sub['Popularity'] = y_pred
df_sub.head()
# Out:
#       Id  Popularity
# 0  27643    0.481340
# 1  27644    0.497880
# 2  27645    0.493316
# 3  27646    0.503848
# 4  27647    0.497961

# %%
df_sub.to_csv('jason_sub_4.csv', index=False)

# %%
df_train.to_csv('./data/train_p.csv', index=False)
df_test.to_csv('./data/test_p.csv', index=False)
